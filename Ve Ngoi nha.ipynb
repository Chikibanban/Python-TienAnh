# %%
# Setting things up
import turtle
house=turtle.Turtle()
house.shapesize(1)
house.shape("turtle")
house.pensize(2)
house.speed(0)

# Drawning the triangle

for i in range (3):
    house.lt(120)
    house.fd(150)

#Drawning the paralellogram

house.fd(300)
house.lt(120)
house.fd(150)
house.lt(60)
house.fd(300)

#Drawning the rectangle
house.lt(120)
house.fd(150)
house.rt(30)

a = 300
b = 90
for i in range (4):
    house.fd(a)
    house.lt(b)

house.rt(b)
house.fd(150)
house.lt(b)
house.fd(235)
house.lt(66.25)
house.fd(165)

#3D the thing
house.bk(165)
house.lt(23)

for i in range (10):
    house.fd(10)
    house.penup()
    house.fd(10)
    house.pendown()
    house.fd(10)

house.lt(90)
for i in range (8):
    house.fd(10)
    house.penup()
    house.fd(10)
    house.pendown()
    house.fd(10)

house.rt(28)

for i in range (5):
    house.fd(10)
    house.penup()
    house.fd(10)
    house.pendown()
    house.fd(10)

house.penup()
house.goto(150,-240)
house.pendown()
house.rt(83)

for i in range (5):
    house.fd(10)
    house.penup()
    house.fd(10)
    house.pendown()
    house.fd(10)



#Ending the code
turtle.exitonclick()
# Out:
# Exception ignored in: <function Image.__del__ at 0x000001C306FF6CB0>
# Traceback (most recent call last):
#   File "C:\Users\hopel\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 4046, in __del__
#     self.tk.call('image', 'delete', self.name)
# RuntimeError: main thread is not in main loop
# Exception ignored in: <function Image.__del__ at 0x000001C306FF6CB0>
# Traceback (most recent call last):
#   File "C:\Users\hopel\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 4046, in __del__
#     self.tk.call('image', 'delete', self.name)
# RuntimeError: main thread is not in main loop
# Exception ignored in: <function Image.__del__ at 0x000001C306FF6CB0>
# Traceback (most recent call last):
#   File "C:\Users\hopel\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 4046, in __del__
#     self.tk.call('image', 'delete', self.name)
# RuntimeError: main thread is not in main loop

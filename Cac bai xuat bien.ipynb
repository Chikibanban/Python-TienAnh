# %%
def phanso():
        import fractions as fr
        print (fr.Fraction(4,5))
        #tao phan so tu so nguyen
        print('tao phan so tu so nguyen')
        print (fr.Fraction(9))
        #tao phan so tu toan tu co mau so
        print ('tao phan so tu toan tu co mau so')
        print (fr.Fraction(2,5))
        #tao phan so thuc
        print(fr.Fraction(2.3))
def toanhoc():
    import math
    print ('xuat so pi ra man hinh')
    print (math.pi)
def tinhSPTamGiac():
    import math
    #ep kieu du lieu
    canha = float(input("nhap canh a:="))
    canhb = float(input("nhap canh b:="))
    canhc = float(input("nhap canh c:="))
    s = (canha + canhb + canhc) / 2
    dientich = math.sqrt (s*(s-canha)*(s-canhb)*(s-canhc))
    print(s)
    print (dientich)
#mo rong: them dieu kien kiem tra 3 canh bat ky tao thanh tam giac
    import math
    #Dieu Kien
    if canha + canhb>canhc and canha-canhb<canhc or canha+canhc>canhb and canha-canhc>canhb or canhb-canhc>canha and canhb+canhc>canha:
        canha = float(input('nhap canh a:='))
        canhb = float(input('nhap canh b:='))
        canhc = float(input('nhap canh c:='))
        TrianglePerimeter = canha + canhb+ canhc
        TriangleArea = math.sqrt(TrianglePerimeter/2*(TrianglePerimeter/2-canha)*(TrianglePerimeter/2-canhb)*(TrianglePerimeter/2-canhc))
        print('Chu vi tam giac la:' + str(TrianglePerimeter))
        print ("Dien tich tam giac la:" + str(TriangleArea))
    else:
        print ("tam giac ko ton tai")

#tinh chu vi va dien tich hinh vuong

def tinhSPhinhvuong():
    import math
    canha = float(input("nhap canh a:="))
    s = canha**2
    p = canha*4
    print("Chu vi hinh vuong la:" + str(s))
    print("Dien tich hinh vuong la:"+ str(p))

def tinhSPChunhat():
    import math
    canha = float(input('nhap canh a:='))
    canhb = float(input('nhap canh b:='))
    Chuvi = (canha+canhb)**2
    DienTich = canha*canhb
    print ("Chu vi hinh chu nhat la:" + str(Chuvi))
    print ("Dien tich hinh chu nhat la:" + str(DienTich))
def tinhSPTron():
    import math
    r = float(input('nhap ban kinh r:='))
    pi = 3.14
    Chuvi = DienTich = pi * r**2
    print ("Chu vi hinh tron la = %.2f" %Chuvi)
    print ("Dien tich tron la = %.2f" %DienTich)

if __name__=="__main__":
        #phanso()
        #toanhoc()
        #tinhSPTamGiac()
        #tinhSPhinhvuong()
        #tinhSPTron()
# Out:
#   File "C:\Users\Hopel\AppData\Local\Temp/ipykernel_5692/3544375195.py", line 71
#     #tinhSPTron()
#                  ^
# IndentationError: expected an indented block after 'if' statement on line 66

# %%
def output():
    print ("this sentence is an output to the screen")
    A= 5
    print ("The value of a is" + str(A))

def my_string():
    my_string = "xin chao"
    i = 1
    for x in my_string:
        print("ky tu tu"+str(i) + x)
        i+=1
    my_string = "xin chao"
    print ("chieu dai cua chuoi la:="+str(len(my_string)))


def txt():
#De bai: Dau vao 2 chuoi: chuoi1, chuoi2
#kiem tra xem chuoi1 co nam trong chuoi2 hay khong
#goi y dung toan tu in
#Vi du
    txt = "chuoi chua ky tu a"
    if "a" in txt:
        print("co A trong chuoi txt")
#Bai lam
def chuoiinput():
    chuoi1 = input("nhap vao chuoi so 1:=")
    chuoi2 = input("nhap vao chuoi so 2:=")
    if chuoi1 in chuoi2:
        print ("OK")
    chuoi1 = input("nhap vao chuoi so 1:=")
    chuoi2 = input("nhap vao chuoi so 2:=")
    if chuoi1 not in chuoi2:
        print ("OK")
        chuoi1 = "xin chao cac ban"
        print(chuoi1[-1])
        chuoi1 = "Xin chao cac ban"
        print(chuoi1[2:5])
def xuatdulieutheodinhdang():
    x=5
    y=10
    print("Gia tri cua x is {} and y is {}".format(x,y))
#Nhap vao mot chuoi cach nhau boi dau ,
#dau do cat chuoi
#sap xep
#Xuat ra man hinh
def xulychuoi():
    #Dinh dang cho item(for cho so vung lap khong xac dinh)
    items = [x for x in input("Nhap vao mot chuoi").split(",")]
    #items gom 4 phan tu ["xin,"chao","lop","python"]
    print("truoc khi sap xep \r\n")
    for a in items:
        print(a)
        items.sort()
    print("sau khi sap xep \r\n")
    for a in items:
            print(a)
    print(",".join(items))

def tinhgeometry():
    import turtle
    import math
    #Tinh chu vi va dien tich cua hinh tron:
    r=int(input("nhap ban kinh:"))
    t = turtle.Turtle()
    t.hideturtle
    t.pensize(3)
    t.color("cyan")
    turtle.done
    c = 2 * math.pi * r
    s = math.pi * r**2
    print("Chu vi cua hinh tron co ban kinh = {r} la {c}".format (r=r, c=c))
    print("Dien tich cua hinh tron co ban kinh = {r} la {s}".format(r=r,s=s))
    
    #Tinh chu vi va dien tich cua hinh vuong
    t = turtle.Turtle()
    t.pensize(5)
    t.color("yellow")
    turtle.done
    a = float(input("Nhap canh a:="))

    c = a*4
    s = a**2
    print("chu vi cua hinh vuong co canh = {a} la {c}".format(a=a,c=c))
    print("dien tich cua hinh vuong co canh = {a} la {s}".format(a=a,s=s))
    
    #Tinh chu va dien tich cua tam giac:

    t.pensize(10)
    t.color("black","orange")
    turtle.done
    b = float(input("Nhap canh b:="))
    c = float(input("Nhap canh c:="))
    
    if a + b > c and a - b < c or a + c > b and a - c > b or b - c > a and a + c >a:
        a = float(input("Nhap canh a:="))
        b = float(input("Nhap canh b:="))
        c = float(input("Nhap canh c:="))
        P = a + b + c
        S = math.sqrt(P/2*(P/2-a)*(P/2-b)*(P/2-c))
        print ("chu vi cua tam giac la: {P} and dien tich cua tam giac la: {S}")
    else:
        print ("tam giac khong ton tai")
    
    turtle.exitonclick()
    
    
    

if __name__ == "__main__":
    #xuatdulieutheodinhdang()
    #chuoiinput()
    #output()
    #my_string()
    #txt()
    #xulychuoi()
    tinhgeometry()
    #tamgiac()
# Out:
# Chu vi cua hinh tron co ban kinh = 10 la 62.83185307179586
# Dien tich cua hinh tron co ban kinh = 10 la 314.1592653589793
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5692/653909319.py in <module>
#     120     #txt()
#     121     #xulychuoi()
# --> 122     tinhgeometry()
#     123     #tamgiac()
#
# ~\AppData\Local\Temp/ipykernel_5692/653909319.py in tinhgeometry()
#      73     turtle.exitonclick()
#      74     #Tinh chu vi va dien tich cua hinh vuong
# ---> 75     t = turtle.Turtle()
#      76     t.hideturtle
#      77     t.pensize(5)
#
# ~\AppData\Local\Programs\Python\Python310\lib\turtle.py in __init__(self, shape, undobuffersize, visible)
#    3812         if Turtle._screen is None:
#    3813             Turtle._screen = Screen()
# -> 3814         RawTurtle.__init__(self, Turtle._screen,
# ...

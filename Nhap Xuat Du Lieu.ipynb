# %%
def output():
    print ("this sentence is an output to the screen")
    A= 5
    print ("The value of a is" + str(A))

def my_string():
    my_string = "xin chao"
    i = 1
    for x in my_string:
        print("ky tu tu"+str(i) + x)
        i+=1
    my_string = "xin chao"
    print ("chieu dai cua chuoi la:="+str(len(my_string)))


def txt():
#De bai: Dau vao 2 chuoi: chuoi1, chuoi2
#kiem tra xem chuoi1 co nam trong chuoi2 hay khong
#goi y dung toan tu in
#Vi du
    txt = "chuoi chua ky tu a"
    if "a" in txt:
        print("co A trong chuoi txt")
#Bai lam
def chuoiinput():
    chuoi1 = input("nhap vao chuoi so 1:=")
    chuoi2 = input("nhap vao chuoi so 2:=")
    if chuoi1 in chuoi2:
        print ("OK")
    chuoi1 = input("nhap vao chuoi so 1:=")
    chuoi2 = input("nhap vao chuoi so 2:=")
    if chuoi1 not in chuoi2:
        print ("OK")
        chuoi1 = "xin chao cac ban"
        print(chuoi1[-1])
        chuoi1 = "Xin chao cac ban"
        print(chuoi1[2:5])
def xuatdulieutheodinhdang():
    x=5
    y=10
    print("Gia tri cua x is {} and y is {}".format(x,y))
#Nhap vao mot chuoi cach nhau boi dau ,
#dau do cat chuoi
#sap xep
#Xuat ra man hinh
def xulychuoi():
    #Dinh dang cho item(for cho so vung lap khong xac dinh)
    items = [x for x in input("Nhap vao mot chuoi").split(",")]
    #items gom 4 phan tu ["xin,"chao","lop","python"]
    print("truoc khi sap xep \r\n")
    for a in items:
        print(a)
        items.sort()
    print("sau khi sap xep \r\n")
    for a in items:
            print(a)
    print(",".join(items))

def tinhgeometry():
    import turtle
    import math
    #Tinh chu vi va dien tich cua hinh tron:
    r = int(input("nhap ban kinh:"))
    t = turtle.Turtle()
    t.hideturtle
    t.pensize(3)
    c = 2 * math.pi * r
    s = math.pi * r**2
    print("Chu vi cua hinh tron co ban kinh = {r} la {c}".format (r=r, c=c))
    print("Dien tich cua hinh tron co ban kinh = {r} la {s}".format(r=r,s=s))
    
    t.fillcolor("black")
    t.begin_fill
    t.dot(r)
    t.end_fill
    
    #Tinh chu vi va dien tich cua hinh vuong
    t = turtle.Turtle()
    t.pensize(5)
    a = float(input("Nhap canh a:="))
    c = a*4
    s = a**2
    print("chu vi cua hinh vuong co canh = {a} la {c}".format(a=a,c=c))
    print("dien tich cua hinh vuong co canh = {a} la {s}".format(a=a,s=s))
    
    t.fillcolor("yellow")
    t.begin_fill()
    for i in range (4):
        t.fd(a)
        t.rt(90)
    t.end_fill()

    #Tinh chu va dien tich cua tam giac:
    
    t.pensize(10)
    b = float(input("Nhap canh b:="))
    c = float(input("Nhap canh c:="))
    
    if a + b > c and a - b < c or a + c > b and a - c > b or b - c > a and a + c >a:
        P = a + b + c
        S = math.sqrt(P/2*(P/2-a)*(P/2-b)*(P/2-c))
        print ("chu vi cua tam giac la: {P} and dien tich cua tam giac la: {S}".format(P=P,S=S))
    else:
        print ("tam giac khong ton tai")

    t.fillcolor("red")
    t.begin_fill
    for i in range (3):
        t.right(120)
        t.fd(a)
    t.end_fill
    turtle.exitonclick()
    

def currencyexchange():
    USD = float(input("Nhap so tien can doi sang VND ="))
    VND = float(input("nhap so tien can doi sang USD ="))
    
    exchagedtoVND = USD/22990
    exchangedtoUSD= VND*22990
    
    print("Doi tien tu VND sang USD la: {exchangedtoUSD} va doi tien tu USD sang VND la: {exchagedtoVND:.3f}".format(exchangedtoUSD=exchangedtoUSD, exchagedtoVND=exchagedtoVND))

def xuatchuoi():
    string1 = "{} {} {}".format("Geeks", "For", "life")
    print ("Chuoi o thu tu mac dinh")
    print(string1)
    
    #chuoi o thu sap xep
    string = "{1} {0} {2}".format("Geeks", "For", "Life")
    print ("\n Chuoi o thu tu sap xep the ky tu")
    
    #Xep theo tu khoa
    string1 = "{l} {g} {f}".format(g="Geeks", f="For", l="life")
    print("\n chuoi o thu tu sap theo ky tu")
    print(string1)

if __name__ == "__main__":
    #xuatdulieutheodinhdang()
    #chuoiinput()
    #output()
    #my_string()
    #txt()
    #xulychuoi()
    #tinhgeometry()
    #currencyexchange()
    #xuatchuoi
